# %%
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import os
import numpy as np
# %matplotlib inline

# %%
# Study data files
mouse_metadata_path = os.path.join("Mouse_metadata.csv")
study_results_path = os.path.join("Study_results.csv")

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single dataset
df = pd.merge(mouse_metadata, study_results, how="left", on=["Mouse ID", "Mouse ID"])
df = df.rename(columns={"Tumor Volume (mm3)":"tumor_volume"})
# Display the data table for preview
df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    tumor_volume  Metastatic Sites
# 0     45.000000                 0
# 1     38.825898                 0
# 2     35.014271                 1
# 3     34.223992                 1
# 4     32.997729                 1

# %%
df.loc[df["Mouse ID"]=="l509"]
# Out:
#     Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 371     l509    Capomulin  Male          17          21          0
# 372     l509    Capomulin  Male          17          21          5
# 373     l509    Capomulin  Male          17          21         10
# 374     l509    Capomulin  Male          17          21         15
# 375     l509    Capomulin  Male          17          21         20
# 376     l509    Capomulin  Male          17          21         25
# 377     l509    Capomulin  Male          17          21         30
# 378     l509    Capomulin  Male          17          21         35
# 379     l509    Capomulin  Male          17          21         40
# 380     l509    Capomulin  Male          17          21         45
#
#      tumor_volume  Metastatic Sites
# 371     45.000000                 0
# 372     45.851193                 0
# 373     46.759074                 0
# 374     47.488599                 1
# 375     48.070452                 2
# 376     44.006257                 2
# 377     44.708055                 2
# 378     40.207289                 2
# 379     40.770813                 2
# 380     41.483008                 3

# %%
# Calculate the number of mice.
len(df["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Check for duplicates and drop
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df=df.drop_duplicates()

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_df["Mouse ID"].unique())
# Out:
# 249

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
regimen_volume_clean_groupby=clean_df[["Drug Regimen", "tumor_volume"]].groupby("Drug Regimen")
tumor_volume_mean=regimen_volume_clean_groupby["tumor_volume"].mean()
tumor_volume_median=regimen_volume_clean_groupby["tumor_volume"].median()
tumor_volume_variance=regimen_volume_clean_groupby["tumor_volume"].var()
tumor_volume_standard_deviation=regimen_volume_clean_groupby["tumor_volume"].std()
tumor_volume_SEM=regimen_volume_clean_groupby["tumor_volume"].sem()
drug_regimen_df=pd.DataFrame({"Mean Tumor Volume":tumor_volume_mean,"Median Tumor Volume":tumor_volume_median,"Tumor Volume Variance":tumor_volume_variance,"Tumor Volume Standard Deviation":tumor_volume_standard_deviation,"Tumor Volume SEM":tumor_volume_SEM})
drug_regimen_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.368318            50.909965              42.278090
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Standard Deviation  Tumor Volume SEM
# Drug Regimen
# Capomulin                            4.994774          0.329346
# Ceftamin                             6.268188          0.469821
# Infubinol                            6.567243          0.492236
# Ketapril                             8.279709          0.603860
# Naftisol                             8.134708          0.596466
# Placebo                              7.821003          0.581331
# Propriva                             6.502160          0.514041
# Ramicane                             4.846308          0.320955
# Stelasyn                             7.710419          0.573111
# Zoniferol                            6.966589          0.516398

# %%
# Using the aggregation method, produce the same summary statistics in a single line
drug_regimen_agg_df=regimen_volume_clean_groupby.agg({"tumor_volume":["mean","median", "var", "std", "sem"]})
drug_regimen_agg_df
# Out:
#              tumor_volume
#                      mean     median        var       std       sem
# Drug Regimen
# Capomulin       40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin        52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol       52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril        55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol        54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo         54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva        52.368318  50.909965  42.278090  6.502160  0.514041
# Ramicane        40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn        54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol       53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
# Create a df with the appropriate columns and groupby the regimen
mice_per_regimen=clean_df[["Mouse ID", "Drug Regimen"]].groupby("Drug Regimen").count()
# Plot
my_plot = mice_per_regimen.plot(kind="bar")
# Set textual properties
plt.title("Mice per Regimen")
plt.ylabel("Number of Mice")
plt.xlabel("Regimens")
# Out:
# Text(0.5, 0, 'Regimens')

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
#create a variable holding the names of the regimens
regimens=clean_df["Drug Regimen"].unique()
#create an array containing the number of mice receiving each treatment
mice_per_regimen_series=mice_per_regimen["Mouse ID"]
mice_per_regimen_array=pd.Series(mice_per_regimen_series).array
x_axis=np.arange(len(mice_per_regimen))
tick_locations=[value for value in x_axis]
#Create a bar chart using matplotlib
#use "x_axis" as the x axis and "mice_per_regimen_array" as the y axis
#use blue and align to center
plt.bar(x_axis, mice_per_regimen["Mouse ID"], color="b",align="center")
#set x axis headers
tick_locations=[value for value in x_axis]
#use the "regimens" variable as the labels
plt.xticks(tick_locations, mice_per_regimen.index, rotation=90)
#set x limits
plt.xlim(-0.75, len(x_axis))
#set y limits
plt.ylim(-0.75,300)
#label the chart
plt.title("Mice Per Regimen")
plt.xlabel("Regimens")
plt.ylabel("Number of Mice")
# Out:
# Text(0, 0.5, 'Number of Mice')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
id_sex_df=clean_df[["Mouse ID", "Sex"]].groupby("Sex").count()
id_sex_df
pie_plot=id_sex_df.plot(subplots=True,kind="pie",autopct="%.0f%%")
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
categories=id_sex_df["Mouse ID"]
colors=["red","blue"]
plt.pie(categories, labels=id_sex_df.index, colors=colors,autopct="%1.0f%%",shadow=True,startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c7f777db20>,
#   <matplotlib.patches.Wedge at 0x1c7f7773130>],
#  [Text(-0.7237151467475075, -0.8283938594462383, 'Female'),
#   Text(0.7237152243073345, 0.8283937916871327, 'Male')],
#  [Text(-0.3947537164077313, -0.45185119606158447, '49%'),
#   Text(0.39475375871309154, 0.4518511591020723, '51%')])

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
final_tumor_volume_df=clean_df[["Mouse ID","Drug Regimen","Timepoint","tumor_volume"]]
# Start by getting the last (greatest) timepoint for each mouse
max_timepoint=final_tumor_volume_df["Timepoint"].max()
final_tumor_volume_max_timepoint_df=final_tumor_volume_df.loc[final_tumor_volume_df["Timepoint"]==max_timepoint]
promising_treatments_df=final_tumor_volume_max_timepoint_df[(final_tumor_volume_max_timepoint_df["Drug Regimen"] == "Capomulin")|(final_tumor_volume_max_timepoint_df["Drug Regimen"] == "Ramicane")|(final_tumor_volume_max_timepoint_df["Drug Regimen"] == "Infubinol")|(final_tumor_volume_max_timepoint_df["Drug Regimen"] == "Ceftamin")]
promising_treatments_df.rename(columns={"tumor_volume":"Final Tumor Volume"})
# Out:
#      Mouse ID Drug Regimen  Timepoint  Final Tumor Volume
# 9        k403     Ramicane         45           22.050126
# 19       s185    Capomulin         45           23.343598
# 29       x401    Capomulin         45           28.484033
# 39       m601    Capomulin         45           28.430964
# 49       g791     Ramicane         45           29.128472
# ...       ...          ...        ...                 ...
# 1797     x822     Ceftamin         45           61.386660
# 1813     y163    Infubinol         45           67.685569
# 1845     y769     Ceftamin         45           68.594745
# 1855     y865     Ceftamin         45           64.729837
# 1872     z581    Infubinol         45           62.754451
#
# [63 rows x 4 columns]

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_df=pd.merge(drug_regimen_df,promising_treatments_df,how="right",on=["Drug Regimen"])
merged_df2=merged_df.rename(columns={"tumor_volume":"Final Tumor Volume"})
merged_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 0 to 62
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Drug Regimen                     63 non-null     object
#  1   Mean Tumor Volume                63 non-null     float64
#  2   Median Tumor Volume              63 non-null     float64
#  3   Tumor Volume Variance            63 non-null     float64
#  4   Tumor Volume Standard Deviation  63 non-null     float64
#  5   Tumor Volume SEM                 63 non-null     float64
#  6   Mouse ID                         63 non-null     object
#  7   Timepoint                        63 non-null     int64
#  8   Final Tumor Volume               63 non-null     float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 4.9+ KB

# %%
# final_tumor_volume_by_regimen_df=merged_df.groupby("Drug Regimen").count()
# final_tumor_volume_by_regimen_df2=final_tumor_volume_by_regimen_df.rename(columns={"tumor_volume":"Final Tumor Volume"}).set_index("Drug Regimen")
# final_tumor_volume_by_regimen_df2
# final_tumor_volume_by_regimen_df
final_tumor_volume_by_regimen_df = pd.DataFrame({'count' : merged_df2.groupby(["Drug Regimen", "Final Tumor Volume"]).size()}).reset_index()
final_tumor_volume_by_regimen_df
print(final_tumor_volume_by_regimen_df.to_string())
# Out:
#    Drug Regimen  Final Tumor Volume  count
# 0     Capomulin           23.343598      1
# 1     Capomulin           28.430964      1
# 2     Capomulin           28.484033      1
# 3     Capomulin           31.023923      1
# 4     Capomulin           31.896238      1
# 5     Capomulin           32.377357      1
# 6     Capomulin           33.329098      1
# 7     Capomulin           34.455298      1
# 8     Capomulin           36.041047      1
# 9     Capomulin           37.074024      1
# 10    Capomulin           37.311846      1
# 11    Capomulin           38.125164      1
# 12    Capomulin           38.846876      1
# 13    Capomulin           38.939633      1
# 14    Capomulin           38.982878      1
# 15    Capomulin           40.159220      1
# 16    Capomulin           40.658124      1
# 17    Capomulin           40.728578      1
# 18    Capomulin           41.483008      1
# 19    Capomulin           41.581521      1
# 20    Capomulin           47.685963      1
# 21     Ceftamin           59.741901      1
# 22     Ceftamin           59.851956      1
# 23     Ceftamin           61.386660      1
# 24     Ceftamin           61.433892      1
# 25     Ceftamin           61.849023      1
# 26     Ceftamin           62.999356      1
# 27     Ceftamin           64.299830      1
# 28     Ceftamin           64.634949      1
# 29     Ceftamin           64.729837      1
# 30     Ceftamin           67.527482      1
# 31     Ceftamin           67.748662      1
# 32     Ceftamin           68.594745      1
# 33     Ceftamin           68.923185      1
# 34    Infubinol           60.918767      1
# 35    Infubinol           62.435404      1
# 36    Infubinol           62.754451      1
# 37    Infubinol           65.525743      1
# 38    Infubinol           66.083066      1
# 39    Infubinol           66.196912      1
# 40    Infubinol           67.685569      1
# 41    Infubinol           67.973419      1
# 42    Infubinol           72.226731      1
# 43     Ramicane           22.050126      1
# 44     Ramicane           29.128472      1
# 45     Ramicane           30.276232      1
# 46     Ramicane           30.564625      1
# 47     Ramicane           30.638696      1
# 48     Ramicane           31.095335      1
# 49     Ramicane           31.560470      1
# 50     Ramicane           32.978522      1
# 51     Ramicane           33.397653      1
# 52     Ramicane           33.562402      1
# 53     Ramicane           36.134852      1
# 54     Ramicane           36.374510      1
# 55     Ramicane           37.225650      1
# 56     Ramicane           37.311236      1
# 57     Ramicane           38.407618      1
# 58     Ramicane           38.810366      1
# 59     Ramicane           40.659006      1
# 60     Ramicane           40.667713      1
# 61     Ramicane           43.047543      1
# 62     Ramicane           45.220869      1

# %%
# Put treatments into a list for for loop (and later for plot labels)
promising_regimens=final_tumor_volume_by_regimen_df["Drug Regimen"].unique()
promising_regimens
# Out:
# array(['Ramicane', 'Capomulin', 'Infubinol', 'Ceftamin'], dtype=object)

# %%
# Create empty list to fill with tumor vol data (for plotting)
tumor_volume_list=[]
for drug in promising_regimens:
    final_tumor_vol=merged_df2.loc[merged_df2["Drug Regimen"]==drug, "Final Tumor Volume"]
    tumor_volume_list.append(final_tumor_vol)
print(tumor_volume_list)
# Out:
# [0     22.050126
# 1     29.128472
# 2     30.276232
# 3     30.564625
# 4     30.638696
# 5     31.560470
# 6     31.095335
# 7     33.397653
# 8     32.978522
# 9     33.562402
# 10    36.134852
# 11    38.810366
# 12    37.225650
# 13    36.374510
# 14    37.311236
# 15    38.407618
# 16    40.659006
# 17    40.667713
# 18    45.220869
# 19    43.047543
# Name: Final Tumor Volume, dtype: float64, 20    23.343598
# 21    28.484033
# 22    28.430964
# 23    31.023923
# 24    31.896238
# 25    32.377357
# 26    33.329098
# 27    34.455298
# 28    37.311846
# 29    36.041047
# 30    37.074024
# 31    38.846876
# 32    38.939633
# 33    38.982878
# 34    38.125164
# 35    40.658124
# 36    40.159220
# 37    40.728578
# 38    41.483008
# 39    41.581521
# 40    47.685963
# Name: Final Tumor Volume, dtype: float64, 41    67.973419
# 42    65.525743
# 43    66.083066
# 44    72.226731
# 45    62.435404
# 46    60.918767
# 47    66.196912
# 48    67.685569
# 49    62.754451
# Name: Final Tumor Volume, dtype: float64, 50    62.999356
# 51    61.849023
# 52    68.923185
# 53    67.748662
# 54    59.851956
# 55    64.299830
# 56    59.741901
# 57    61.433892
# 58    67.527482
# 59    64.634949
# 60    61.386660
# 61    68.594745
# 62    64.729837
# Name: Final Tumor Volume, dtype: float64]

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers.
# Locate the rows which contain mice on each drug and get the tumor volumes
# Determine outliers using upper and lower bounds

#Create dfs for each promising regimen
ramicane_df=final_tumor_volume_by_regimen_df.loc[final_tumor_volume_by_regimen_df["Drug Regimen"]=="Ramicane"]
capomulin_df=final_tumor_volume_by_regimen_df.loc[final_tumor_volume_by_regimen_df["Drug Regimen"]=="Capomulin"]
infubinol_df=final_tumor_volume_by_regimen_df.loc[final_tumor_volume_by_regimen_df["Drug Regimen"]=="Infubinol"]
ceftamin_df=final_tumor_volume_by_regimen_df.loc[final_tumor_volume_by_regimen_df["Drug Regimen"]=="Ceftamin"]

# %%
# Ramicane
final_ramicane_tumor_volume=ramicane_df["Final Tumor Volume"]
quartiles=final_ramicane_tumor_volume.quantile([.25,.5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[.75]
print(f"Lowerq:{lowerq}")
print(f"Upperq:{upperq}")
iqr=upperq - lowerq
lower_bound=lowerq-(1.5*iqr)
upper_bound=upperq+(1.5*iqr)
print(f"The IQR is: {iqr}")
print(f"LowerBound:{lower_bound}")
print(f"UpperBound:{upper_bound}")
outliers=ramicane_df.loc[(ramicane_df['Final Tumor Volume'] < lower_bound) | (ramicane_df['Final Tumor Volume'] > upper_bound)]
print(outliers)
ramicane_df
# Out:
# Lowerq:30.981175224999998
# Upperq:38.508305307499995
# The IQR is: 7.527130082499998
# LowerBound:19.690480101250003
# UpperBound:49.79900043124999
# Empty DataFrame
# Columns: [Drug Regimen, Final Tumor Volume, count]
# Index: []
#    Drug Regimen  Final Tumor Volume  count
# 43     Ramicane           22.050126      1
# 44     Ramicane           29.128472      1
# 45     Ramicane           30.276232      1
# 46     Ramicane           30.564625      1
# 47     Ramicane           30.638696      1
# 48     Ramicane           31.095335      1
# 49     Ramicane           31.560470      1
# 50     Ramicane           32.978522      1
# 51     Ramicane           33.397653      1
# 52     Ramicane           33.562402      1
# 53     Ramicane           36.134852      1
# 54     Ramicane           36.374510      1
# 55     Ramicane           37.225650      1
# 56     Ramicane           37.311236      1
# 57     Ramicane           38.407618      1
# 58     Ramicane           38.810366      1
# 59     Ramicane           40.659006      1
# 60     Ramicane           40.667713      1
# 61     Ramicane           43.047543      1
# 62     Ramicane           45.220869      1

# %%
# Capomulin
final_capomulin_tumor_volume=capomulin_df["Final Tumor Volume"]
quartiles=final_capomulin_tumor_volume.quantile([.25,.5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[.75]
print(f"Lowerq:{lowerq}")
print(f"Upperq:{upperq}")
iqr=upperq - lowerq
lower_bound=lowerq-(1.5*iqr)
upper_bound=upperq+(1.5*iqr)
print(f"The IQR is: {iqr}")
print(f"LowerBound:{lower_bound}")
print(f"UpperBound:{upper_bound}")
outliers=capomulin_df.loc[(capomulin_df['Final Tumor Volume'] < lower_bound) | (capomulin_df['Final Tumor Volume'] > upper_bound)]
print(outliers)
capomulin_df
# Out:
# Lowerq:32.37735684
# Upperq:40.1592203
# The IQR is: 7.781863460000004
# LowerBound:20.70456164999999
# UpperBound:51.83201549
# Empty DataFrame
# Columns: [Drug Regimen, Final Tumor Volume, count]
# Index: []
#    Drug Regimen  Final Tumor Volume  count
# 0     Capomulin           23.343598      1
# 1     Capomulin           28.430964      1
# 2     Capomulin           28.484033      1
# 3     Capomulin           31.023923      1
# 4     Capomulin           31.896238      1
# 5     Capomulin           32.377357      1
# 6     Capomulin           33.329098      1
# 7     Capomulin           34.455298      1
# 8     Capomulin           36.041047      1
# 9     Capomulin           37.074024      1
# 10    Capomulin           37.311846      1
# 11    Capomulin           38.125164      1
# 12    Capomulin           38.846876      1
# 13    Capomulin           38.939633      1
# 14    Capomulin           38.982878      1
# 15    Capomulin           40.159220      1
# 16    Capomulin           40.658124      1
# 17    Capomulin           40.728578      1
# 18    Capomulin           41.483008      1
# 19    Capomulin           41.581521      1
# 20    Capomulin           47.685963      1

# %%
# Infubinol
final_infubinol_tumor_volume=infubinol_df["Final Tumor Volume"]
quartiles=final_infubinol_tumor_volume.quantile([.25,.5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[.75]
print(f"Lowerq:{lowerq}")
print(f"Upperq:{upperq}")
iqr=upperq - lowerq
lower_bound=lowerq-(1.5*iqr)
upper_bound=upperq+(1.5*iqr)
print(f"The IQR is: {iqr}")
print(f"LowerBound:{lower_bound}")
print(f"UpperBound:{upper_bound}")
outliers=infubinol_df.loc[(infubinol_df['Final Tumor Volume'] < lower_bound) | (infubinol_df['Final Tumor Volume'] > upper_bound)]
print(outliers)
infubinol_df.head(20)
# Out:
# Lowerq:62.75445141
# Upperq:67.68556862
# The IQR is: 4.9311172099999965
# LowerBound:55.35777559500001
# UpperBound:75.08224443499999
# Empty DataFrame
# Columns: [Drug Regimen, Final Tumor Volume, count]
# Index: []
#    Drug Regimen  Final Tumor Volume  count
# 34    Infubinol           60.918767      1
# 35    Infubinol           62.435404      1
# 36    Infubinol           62.754451      1
# 37    Infubinol           65.525743      1
# 38    Infubinol           66.083066      1
# 39    Infubinol           66.196912      1
# 40    Infubinol           67.685569      1
# 41    Infubinol           67.973419      1
# 42    Infubinol           72.226731      1

# %%
# Ceftamin
final_ceftamin_tumor_volume=ceftamin_df["Final Tumor Volume"]
quartiles=final_ceftamin_tumor_volume.quantile([.25,.5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[.75]
print(f"Lowerq:{lowerq}")
print(f"Upperq:{upperq}")
iqr=upperq - lowerq
lower_bound=lowerq-(1.5*iqr)
upper_bound=upperq+(1.5*iqr)
print(f"The IQR is: {iqr}")
print(f"LowerBound:{lower_bound}")
print(f"UpperBound:{upper_bound}")
outliers=ceftamin_df.loc[(ceftamin_df['Final Tumor Volume'] < lower_bound) | (ceftamin_df['Final Tumor Volume'] > upper_bound)]
print(outliers)
ceftamin_df
# Out:
# Lowerq:61.43389223
# Upperq:67.52748237
# The IQR is: 6.093590140000003
# LowerBound:52.29350701999999
# UpperBound:76.66786758
# Empty DataFrame
# Columns: [Drug Regimen, Final Tumor Volume, count]
# Index: []
#    Drug Regimen  Final Tumor Volume  count
# 21     Ceftamin           59.741901      1
# 22     Ceftamin           59.851956      1
# 23     Ceftamin           61.386660      1
# 24     Ceftamin           61.433892      1
# 25     Ceftamin           61.849023      1
# 26     Ceftamin           62.999356      1
# 27     Ceftamin           64.299830      1
# 28     Ceftamin           64.634949      1
# 29     Ceftamin           64.729837      1
# 30     Ceftamin           67.527482      1
# 31     Ceftamin           67.748662      1
# 32     Ceftamin           68.594745      1
# 33     Ceftamin           68.923185      1

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig, ax=plt.subplots()
ax.set_title("Final Tumor Volume")
ax.boxplot([final_ramicane_tumor_volume,final_capomulin_tumor_volume,final_ceftamin_tumor_volume,final_infubinol_tumor_volume])
ax.set_xticklabels(["Ramicane","Capomulin","Ceftamin","Infubinol"])
# Out:
# [Text(1, 0, 'Ramicane'),
#  Text(2, 0, 'Capomulin'),
#  Text(3, 0, 'Ceftamin'),
#  Text(4, 0, 'Infubinol')]

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
l509_df=df.loc[df["Mouse ID"]=="l509"]
l509_df_cleaned=l509_df[["Mouse ID", "tumor_volume","Timepoint"]]
l509_df_cleaned.plot("Timepoint")
# Out:
# <AxesSubplot:xlabel='Timepoint'>

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
# capomulin_df=df[df["Drug Regimen"]=="Capomulin"]
# capomulin_volume_weight_df=capomulin_df[["tumor_volume","Weight (g)"]]
# avg_tumor_volume=capomulin_volume_weight_df["tumor_volume"].mean()
# mouse_weight=capomulin_volume_weight_df["Weight (g)"]
# scatter_df=pd.DataFrame({"Volume":avg_tumor_volume,"Weight":mouse_weight})
# scatter_df.plot.scatter("Weight","Volume")
weight_volume_df=capomulin_df[["Mouse ID","Weight (g)","tumor_volume"]]
scatter_df=weight_volume_df.groupby("Mouse ID").mean()
scatter_df.plot.scatter("Weight (g)","tumor_volume")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, b128 to y793
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weight (g)    25 non-null     int64
#  1   tumor_volume  25 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 600.0+ bytes

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
